# %%
import pandas as pd
import glob, os

# %%
labels1 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'LTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels2 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'LTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels3 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'LTA', 'RTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels4 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'LTA', 'RTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels5 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'LTA', 'RTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels6 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'LTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels7 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'LTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels81 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'LTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels82 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'RGS', 'IO', 'ECG', 'LTA', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels9 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'LTA', 'RTA', 'IO', 'RGS', 'ECG', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels10 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'LTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels11 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'LTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
labels12 = ['number', 'timestamp', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6', 'RTA', 'LTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']

ordered_labels = ['timestamp', 'LTA', 'RTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']

# %%
df1 = pd.read_csv('C:\\Users\\Kha\\Documents\\Waterloo\\4A\\SYDE 599\\Project\\data\\Filtered Data\\001\\task_1.txt', header=None)
df1.columns = labels1
df1 = df1.drop(labels=['number', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6'], axis=1)
df1
# Out:
#         number     timestamp    RTA    LTA    IO    ECG    RGS     accel_x1  \
# 0            0      12:04:38 -855.0   15.5 -11.0 -369.0 -313.0  8019.000000
# 1            1  12:04:38.002 -918.0   23.0 -10.5 -356.5 -200.0  8012.323784
# 2            2  12:04:38.004 -891.5   74.0 -10.5 -269.5   -7.5  8013.199022
# 3            3  12:04:38.006 -731.0  247.0 -10.5 -242.0  301.0  8021.112370
# 4            4  12:04:38.008 -607.5  378.0 -10.5 -245.5  562.0  8035.550478
# ...        ...           ...    ...    ...   ...    ...    ...          ...
# 180496  180496  12:10:38.992 -598.5  -37.5 -19.5  193.0 -194.0  8100.139833
# 180497  180497  12:10:38.994 -607.0  -43.5 -18.5  201.5 -211.0  8094.448841
# 180498  180498  12:10:38.996 -568.5  -13.5 -17.5  241.5 -170.5  8089.087934
# 180499  180499  12:10:38.998 -545.5  -24.5 -17.0  248.5 -143.5  8085.218018
# 180500  180500      12:10:39 -537.0  -39.5 -17.0  243.0 -139.0  8084.000000
#
# ...

# %%
df1 = df1[ordered_labels]
df1
# Out:
#         number     timestamp    LTA    RTA    IO    ECG    RGS     accel_x1  \
# 0            0      12:04:38   15.5 -855.0 -11.0 -369.0 -313.0  8019.000000
# 1            1  12:04:38.002   23.0 -918.0 -10.5 -356.5 -200.0  8012.323784
# 2            2  12:04:38.004   74.0 -891.5 -10.5 -269.5   -7.5  8013.199022
# 3            3  12:04:38.006  247.0 -731.0 -10.5 -242.0  301.0  8021.112370
# 4            4  12:04:38.008  378.0 -607.5 -10.5 -245.5  562.0  8035.550478
# ...        ...           ...    ...    ...   ...    ...    ...          ...
# 180496  180496  12:10:38.992  -37.5 -598.5 -19.5  193.0 -194.0  8100.139833
# 180497  180497  12:10:38.994  -43.5 -607.0 -18.5  201.5 -211.0  8094.448841
# 180498  180498  12:10:38.996  -13.5 -568.5 -17.5  241.5 -170.5  8089.087934
# 180499  180499  12:10:38.998  -24.5 -545.5 -17.0  248.5 -143.5  8085.218018
# 180500  180500      12:10:39  -39.5 -537.0 -17.0  243.0 -139.0  8084.000000
#
# ...

# %%
df1.describe()
# Out:
#               number            LTA            RTA             IO  \
# count  180501.000000  180501.000000  180501.000000  180501.000000
# mean    90250.000000       0.271522      -0.222348       0.171611
# std     52106.294807     934.616601    2969.014416      44.845060
# min         0.000000   -4060.500000   -5869.000000    -391.500000
# 25%     45125.000000    -542.000000   -3136.000000     -18.500000
# 50%     90250.000000     -70.500000     556.000000      -0.500000
# 75%    135375.000000     402.000000    2782.000000      17.500000
# max    180500.000000    5477.500000    6117.000000     302.500000
#
#                  ECG            RGS       accel_x1       accel_y1  \
# count  180501.000000  180501.000000  180501.000000  180501.000000
# mean       -1.173675      -1.644944    8377.385010   -1393.771096
# std      2571.621576    3099.037376    4407.496656    5231.698654
# min     -5126.000000   -5613.500000  -36396.879263  -40896.002210
# ...

# %%
def clean_data(patient_number, path, file_name, labels):
    ordered_labels = ['timestamp', 'LTA', 'RTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
    labels_to_drop =['number', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6']
    output_path = 'C:\\Users\\Kha\\Documents\\Waterloo\\4A\\SYDE 599\\Project\\cleaned_data\\'
    
    df = pd.read_csv(path, header=None)
    df.columns = labels
    df = df.drop(labels = labels_to_drop, axis = 1)
    df = df[ordered_labels]
#     print(df)
    
    if(patient_number < 10):
        output_file_name = output_path + '00' + str(patient_number) + '_' + file_name
    else:
        output_file_name = output_path + '0' + str(patient_number) + '_' + file_name
    
    df.index.name = 'index'
    df.to_csv(output_file_name, header=False)
    pass

def clean_data_8(eight_number, path, file_name, labels):
    ordered_labels = ['timestamp', 'LTA', 'RTA', 'IO', 'ECG', 'RGS', 'accel_x1', 'accel_y1', 'accel_z1', 'gyro_x1', 'gyro_y1', 'gyro_z1', 'NC1', 'accel_x2', 'accel_y2', 'accel_z2', 'gyro_x2', 'gyro_y2', 'gyro_z2', 'NC2', 'accel_x3', 'accel_y3', 'accel_z3', 'gyro_x3', 'gyro_y3', 'gyro_z3', 'NC3', 'accel_x4', 'accel_y4', 'accel_z4', 'gyro_x4', 'gyro_y4', 'gyro_z4', 'SC', 'label']
    labels_to_drop =['number', 'FP1', 'FP2', 'F3', 'F4', 'C4', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'P7', 'P8', 'FZ', 'CZ', 'PZ', 'FC1', 'FC2', 'CP1', 'CP2', 'FC5', 'FC6', 'CP5', 'CP6']
    output_path = 'C:\\Users\\Kha\\Documents\\Waterloo\\4A\\SYDE 599\\Project\\cleaned_data\\'
    
    df = pd.read_csv(path, header=None)
    df.columns = labels
    df = df.drop(labels = labels_to_drop, axis = 1)
    df = df[ordered_labels]
#     print(df)
    
#     if(patient_number < 10):
#         output_file_name = output_path + '00' + str(patient_number) + '_' + file_name
#     else:
#         output_file_name = output_path + '0' + str(patient_number) + '_' + file_name

    output_file_name = output_path + '008' + str(eight_number) + '_' + file_name
    
    df.index.name = 'index'
    df.to_csv(output_file_name, header=False)
    pass
    pass

# %%
labels_list = [labels1, labels2, labels3, labels4, labels5, labels6, labels7, 'temp', labels9, labels10, labels11, labels12]
raw_path = 'C:\\Users\\Kha\\Documents\\Waterloo\\4A\\SYDE 599\\Project\\data\\Filtered Data\\0'
for i in range(1, 13):
    if(i != 8):
        if(i < 10):
#             print(len(labels_list[i-1]))
            path = raw_path + '0' + str(i)
            os.chdir(path)
            for file in glob.glob("*.txt"):
                path_with_file = path + '\\' + file
                df = clean_data(patient_number = i, path=path_with_file, file_name=file, labels=labels_list[i-1])

            pass
        else:
            path = raw_path + str(i)
            os.chdir(path)
            for file in glob.glob("*.txt"):
                path_with_file = path + '\\' + file
                clean_data(patient_number = i, path=path_with_file, file_name=file, labels=labels_list[i-1])

            pass
    else:
        path1 = 'C:\\Users\\Kha\\Documents\\Waterloo\\4A\\SYDE 599\\Project\\data\\Filtered Data\\008\\OFF_1'
        for file in glob.glob("*.txt"):
            path_with_file = path1 + '\\' + file
            clean_data_8(eight_number = 1, path=path_with_file, file_name=file, labels=labels81)
        
        path2 = 'C:\\Users\\Kha\\Documents\\Waterloo\\4A\\SYDE 599\\Project\\data\\Filtered Data\\008\\OFF_2'
        for file in glob.glob("*.txt"):
            path_with_file = path2 + '\\' + file
            clean_data_8(eight_number = 2, path=path_with_file, file_name=file, labels=labels82)
        pass
